# %% [markdown]
# (
# (
# sp|Q31Q05|RAF1_SYNE7:0.47550,
# sp|P04718|RBL2_RHORU:0.34890)
# :0.24878,
# sp|P00879|RBL_NOSS1:0.09197,
# sp|O03042|RBL_ARATH:0.08276);

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Все выбранные белки – это рибулозо-1,5-бисфосфат-карбоксилаза/оксигеназа (RuBisCO), ключевой фермент фотосинтеза, участвующий в фиксации CO₂
#
# **P04718 · RBL2_RHORU** (Rhodospirillum rubrum) – RuBisCO типа II, характерная для некоторых фотосинтетических бактерий
# **O03042 · RBL_ARATH** (Arabidopsis thaliana) – классическая RuBisCO типа I, свойственная высшим растениям
# **P00879 · RBL_NOSS1** (Nostoc sp.) – RuBisCO типа I у нитчатой цианобактерии, способной к азотфиксации
# **Q31Q05 · RAF1_SYNE7** (Synechococcus elongatus) – RuBisCO типа I у одноклеточной цианобактерии
# Вывод:
# RuBisCO встречается у разных фотосинтетических организмов, но у Rhodospirillum rubrum представлена более примитивная форма (тип II), что отражается в филогенетическом дереве.
